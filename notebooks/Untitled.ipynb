# %% [markdown]
# # Primer análisis con Pandas
#
# Este notebook es un ejercicio inicial para:
# - verificar que el entorno funciona
# - practicar Pandas básico
# - entender el flujo de trabajo en Jupyter
#
# Autor: Pau
# Fecha: 2025-12-26
